# %%
#import tools


import tabula
import pandas as pd

#Create dataframe 

file_path = r"C:\Users\lucab\Desktop\food-carbon-footprint-index-2018-nu3-en.pdf"
df = tabula.read_pdf(r"C:\Users\lucab\Desktop\food-carbon-footprint-index-2018-nu3-en.pdf", pages = "all", multiple_tables = True)
#df
#df = df.drop(
   # ["Animal Products"],
   #  axis = 0,
#)
#df
print(df)
# Out:
# [    Unnamed: 0 Unnamed: 1    Unnamed: 2  \
# 0          NaN        NaN           NaN
# 1          NaN        NaN           NaN
# 2          NaN        NaN           NaN
# 3          NaN        NaN  Supplied for
# 4          NaN        NaN           NaN
# ..         ...        ...           ...
# 109        102       Iran          0.00
# 110        103   Tanzania          0.32
# 111        104    Senegal          0.94
# 112        105       Peru          3.85
# 113        106  Nicaragua          3.38
#
#                                  Unnamed: 3    Unnamed: 4  \
# 0    Difference between Animal Pork Poultry          Beef
# 1                                       NaN           NaN
# 2                                       NaN           NaN
# 3                              Supplied for  Supplied for
# 4                                        Kg            Kg
# ..                                      ...           ...
# 109                              0.00 25.38    27.26 3.58
# ...
